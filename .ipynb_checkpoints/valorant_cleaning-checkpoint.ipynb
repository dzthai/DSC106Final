# %%
import sqlite3

con = sqlite3.connect("valorant.sqlite")
cur = con.cursor()

# %%
def sql_fetch(con):

    cursorObj = con.cursor()

    cursorObj.execute('SELECT name from sqlite_master where type= "table"')

    print(cursorObj.fetchall())

sql_fetch(con)
# Out:
# [('Matches',), ('Games',), ('Game_Rounds',), ('Game_Scoreboard',)]

# %%
import pandas as pd

df_games = pd.read_sql_query("SELECT * FROM Games;", con)
df_gs = pd.read_sql_query("SELECT * FROM Game_Scoreboard;", con)
df_gr = pd.read_sql_query("SELECT * FROM Game_Rounds;", con)
df_ma = pd.read_sql_query("SELECT * FROM Matches;", con)
df_temp = pd.merge(df_games,df_gs, how='inner')
df_temp2 = pd.merge(df_gr, df_temp, how='inner')
df = pd.merge(df_temp2, df_ma, how='inner')

# %%
df.columns
# Out:
# Index(['GameID', 'Team1ID', 'Team2ID', 'RoundHistory', 'MatchID', 'Map',
#        'Team1', 'Team2', 'Winner', 'Team1_TotalRounds', 'Team2_TotalRounds',
#        'Team1_SideFirstHalf', 'Team2_SideFirstHalf', 'Team1_RoundsFirstHalf',
#        'Team1_RoundsSecondtHalf', 'Team1_RoundsOT', 'Team2_RoundsFirstHalf',
#        'Team2_RoundsSecondtHalf', 'Team2_RoundsOT', 'Team1_PistolWon',
#        'Team1_Eco', 'Team1_EcoWon', 'Team1_SemiEco', 'Team1_SemiEcoWon',
#        'Team1_SemiBuy', 'Team1_SemiBuyWon', 'Team1_FullBuy',
#        'Team1_FullBuyWon', 'Team2_PistolWon', 'Team2_Eco', 'Team2_EcoWon',
#        'Team2_SemiEco', 'Team2_SemiEcoWon', 'Team2_SemiBuy',
#        'Team2_SemiBuyWon', 'Team2_FullBuy', 'Team2_FullBuyWon', 'PlayerID',
#        'PlayerName', 'TeamAbbreviation', 'Agent', 'ACS', 'Kills', 'Deaths',
#        'Assists', 'PlusMinus', 'KAST_Percent', 'ADR', 'HS_Percent',
#        'FirstKills', 'FirstDeaths', 'FKFD_PlusMinus', 'Num_2Ks', 'Num_3Ks',
#        'Num_4Ks', 'Num_5Ks', 'OnevOne', 'OnevTwo', 'OnevThree', 'OnevFour',
#        'OnevFive', 'Econ', 'Plants', 'Defuses', 'Date', 'Patch', 'EventID',
#        'EventName', 'EventStage', 'Team1_MapScore', 'Team2_MapScore'],
#       dtype='object')

# %%
df.drop(['EventName','EventStage','RoundHistory','Team1_RoundsOT',
                         'Team2_RoundsOT','Patch','EventID','PlusMinus', 'Team1_TotalRounds'
        ,'Team2_TotalRounds', 'Team1_RoundsSecondtHalf', 'Team2_RoundsFirstHalf',
       'Team2_RoundsSecondtHalf', 'Team1_PistolWon', 'Team1_Eco',
       'Team1_EcoWon', 'Team1_SemiEco', 'Team1_SemiEcoWon', 'Team1_SemiBuy',
       'Team1_SemiBuyWon', 'Team1_FullBuy', 'Team1_FullBuyWon',
       'Team2_PistolWon', 'Team2_Eco', 'Team2_EcoWon', 'Team2_SemiEco',
       'Team2_SemiEcoWon', 'Team2_SemiBuy', 'Team2_SemiBuyWon',
       'Team2_FullBuy', 'Team2_FullBuyWon', 'KAST_Percent','FirstDeaths',
         'FKFD_PlusMinus','OnevOne','OnevTwo', 'OnevThree','OnevFour','OnevFive', 
         'Econ','Team1_MapScore','Plants','Defuses', 'Team1_RoundsFirstHalf','Team1_SideFirstHalf', 'Team2_SideFirstHalf','Team2_MapScore'],inplace=True, axis=1)

# %%
df.head()
# Out:
#   GameID  Team1ID  Team2ID MatchID     Map                Team1     Team2  \
# 0  60894     6903     6020   62393  Breeze  Booster Seat Gaming  Pho Real
# 1  60894     6903     6020   62393  Breeze  Booster Seat Gaming  Pho Real
# 2  60894     6903     6020   62393  Breeze  Booster Seat Gaming  Pho Real
# 3  60894     6903     6020   62393  Breeze  Booster Seat Gaming  Pho Real
# 4  60894     6903     6020   62393  Breeze  Booster Seat Gaming  Pho Real
#
#                 Winner PlayerID PlayerName  ... Deaths Assists    ADR  \
# 0  Booster Seat Gaming     8419     Reduxx  ...   10.0     3.0  195.0
# 1  Booster Seat Gaming      466     ChurmZ  ...   10.0     7.0  161.0
# 2  Booster Seat Gaming     3712   diaamond  ...    9.0     8.0  148.0
# 3  Booster Seat Gaming     5099     Boltzy  ...   12.0     2.0  141.0
# 4  Booster Seat Gaming     3983     Virtyy  ...   13.0     3.0   55.0
#
#    HS_Percent  FirstKills  Num_2Ks  Num_3Ks  Num_4Ks  Num_5Ks  \
# 0        0.31         4.0      2.0      2.0      2.0      0.0
# 1        0.16         1.0      3.0      1.0      0.0      0.0
# 2        0.27         3.0      1.0      2.0      0.0      0.0
# 3        0.19         3.0      3.0      1.0      0.0      0.0
# 4        0.22         3.0      1.0      0.0      0.0      0.0
#
#                   Date
# 0  2022-01-08 15:30:00
# 1  2022-01-08 15:30:00
# 2  2022-01-08 15:30:00
# 3  2022-01-08 15:30:00
# 4  2022-01-08 15:30:00
#
# [5 rows x 24 columns]

# %%
df.loc[0]
# Out:
# GameID                            60894
# Team1ID                            6903
# Team2ID                            6020
# MatchID                           62393
# Map                              Breeze
# Team1               Booster Seat Gaming
# Team2                          Pho Real
# Winner              Booster Seat Gaming
# PlayerID                           8419
# PlayerName                       Reduxx
# TeamAbbreviation                   Boos
# Agent                              jett
# ACS                               313.0
# Kills                              24.0
# Deaths                             10.0
# Assists                             3.0
# ADR                               195.0
# HS_Percent                         0.31
# FirstKills                          4.0
# Num_2Ks                             2.0
# Num_3Ks                             2.0
# Num_4Ks                             2.0
# Num_5Ks                             0.0
# Date                2022-01-08 15:30:00
# Name: 0, dtype: object

# %%
import re

import requests
from bs4 import BeautifulSoup

# %%
region = {
    "na": "north-america",
    "eu": "europe",
    "ap": "asia-pacific",
    "la": "latin-america",
    "la-s": "la-s",
    "la-n": "la-n",
    "oce": "oceania",
    "kr": "korea",
    "mn": "mena",
    "gc": "game-changers",
    "br": "Brazil",
    "ch": "china",
}

headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0",
}

# %%
def vlr_team(team_num):
        URL = "https://www.vlr.gg/team/" + str(team_num)
        html = requests.get(URL, headers=headers)
        soup = BeautifulSoup(html.content, "lxml")
        status = html.status_code

        base = soup.find(class_=re.compile("col-container"))
        containers = base.find_all(class_="team-header")

        result = []
        for container in containers:
            # column 1
            name = container.find(class_=re.compile("team-header-name")).text.strip()

            # column 2 - logo
            logo_container = container.find(class_=re.compile("wf-avatar team-header-logo"))
            img = logo_container.find("img")
            logo = "https:" + img["src"]

            # column 2 - ctry
            country = container.find(class_=re.compile("team-header-country")).text.strip()

            result.append(
                {
                    "name": name,
                    "country": country,
                    "logo": logo,
                }
            )

        data = {"data": result}

        if status != 200:
            return "nope"
        return data

# %%
def get_country(playerID):
        URL = "https://www.vlr.gg/team/" + str(team_num)
        html = requests.get(URL, headers=headers)
        soup = BeautifulSoup(html.content, "lxml")
        status = html.status_code

        base = soup.find(class_=re.compile("col-container"))
        containers = base.find_all(class_="team-header")

        result = []
        for container in containers:
            # column 1
            name = container.find(class_=re.compile("team-header-name")).text.strip()

            # column 2 - logo
            logo_container = container.find(class_=re.compile("wf-avatar team-header-logo"))
            img = logo_container.find("img")
            logo = "https:" + img["src"]

            # column 2 - ctry
            country = container.find(class_=re.compile("team-header-country")).text.strip()

            result.append(
                {
                    "name": name,
                    "country": country,
                    "logo": logo,
                }
            )

        data = {"data": result}

        if status != 200:
            return "nope"
        return data

# %%
import sys 

teams1 = list(set(df['Team1ID']))
teams2 = df['Team2ID']

# %%
result = {}

for i in range(len(teams1)):
    data = vlr_team(teams1[i])
    if (data == 'nope'):
        continue
    doot = pd.json_normalize(data)  
    if ('\n' in doot['data'][0][0]['name']):
        abbrev = doot['data'][0][0]['name'].split('\n')[1]
        if abbrev == '(inactive)':
            continue
        name = doot['data'][0][0]['name'].split('\n')[0]
        sys.stdout.write(abbrev + " " + name + '\n')
        result[abbrev] = name
    else:
        result[doot['data'][0][0]['name']] = doot['data'][0][0]['name']
# Out:
# SEN Sentinels
# NIP Ninjas in Pyjamas
# DIG Dignitas
# Sonii Team Sonii
# Prospects Prospects
# GEN Gen.G
# SFCS StartedFromCS
# DW Dire Wolves
# 123 fish123
# SHID Shidiots
# SEAL6 Seal Team 6
# HyP HypHypHyp
# 2G4L TooGoodForLan
# nmDM need more DM
# OBSD Obsidian Esports
# INST L'institut
# Inet InetGamer
# Jbzz Team Jbzz
# DPE DPE
# FB Fordon Boars
# DC DREAMCHASERS
# VIK Vikingekrig Esports
# WP Worst Players
# NES NeverEndingStory
# C123 Clan123
# aL Absolute Legends
# Spectralis Team Spectralis
# PP PartyParrots
# IMT Immortals
# RC REJECT
# FVT FishkaVTom
# CLT Charlotte Phoenix
# OCH Team ocheon2
# 100T 100 Thieves
# VLK Team Valkia
# SOL Team Solaaaa
# BLA Team blackelespanolito
# LOT Team Lothar
# WTC Team wtcN
# MYM Team mym_alkapone
# BLU Team blue_mx
# ROB Team RobertoCein
# STP Team StPeach
# FLM Team fl0m
# STS Team Sh0ts
# MND Team Mendo
# JF Team Jordan Fisher
# PN Team Paula Nobre
# SCY Team Sacy
# MCH Team mch
# SAB Team sabagod2
# YMT Team YamatoN
# KEN Team kennymcc
# SS-R SunSister Rapid
# DYL Team DylanteroLIVE
# C9 Cloud9
# C7 Code7
# VS Vision Strikers
# paiN paiN Gaming
# CAG CYCLOPS athlete gaming
# DTN DeToNator
# Warthox Warthox Esport
# TWT together we are terrific
# 303 Orange 303 Esports Orange
# W2F Way 2 French
# CN China Nguyen
# NKY Team nookyyy
# PC Purple Cobras
# GLB Gamelanders Blue
# FKL Falkol eSports
# G2 G2 Esports
# QS Quantum Strikers
# AG AVALON Gaming
# PD Pants Down
# RNT RipNTear
# GVN GVNG
# BMN BAKEMON
# CR Crazy Raccoon
# DGW DetonatioN Gaming White
# JUP Absolute JUPITER
# LAG LAG Gaming
# SZ SCARZ
# SGG Sengoku Gaming
# NR Nora-Rengo
# SUP Spot Up
# LMND Lemonade Stand
# TU Team Turkey
# TG THOSE GUYS
# WAVE Wave Esports
# 0.5 nolpenki
# BF Bottom Fraggers
# FaZe FaZe Clan
# DV Divine Vendetta
# EXS Exalted Esports
# CC CITRON CHIEN
# B7 B7 Warriors
# 5gg 5gg
# FG Furious Gaming
# INF Infinity Esports
# 9z 9z Team
# Estral Estral Esports
# AGM Arctic Gaming Mexico
# EXO EXO Clan
# DT Demon Time
# XZ team xz
# DXG DivisionX Gaming
# DOS Dawn of Stars
# BBL BBL Esports
# BD Black Dragons
# TERROR TERROR.NET
# VKS Team Vikings
# NOTB NOTRAB
# MMG Mamba Mode Gaming
# PiP PiP PiP PiP
# oNe Team oNe
# NV Envy
# CWK Crab Walk Killers
# LAUNCH Team Launch
# OPS OverPalaStrike
# PL Pillow
# CTRL Control
# OPP Opportunists
# QSM Question Mark
# BME BOOM Esports
# RNG Renegades
# COL Complexity
# BIG BIG
# BBG Built By Gamers
# TL Team Liquid
# L4O looking4org
# ML Morning Light
# PBz Pretty Boyz
# H/L Homeless
# VTX Vertexo
# TYE tyeasy
# FF Fusion Fraggers
# ahq ahq e-Sports Club
# AAA Attack All Around
# LDS LEGENDs
# TTM Totem Providence
# NM No Mercy
# BBI BlackBird Ignis
# FAV FAV gaming
# LH Lunatic-Hai
# VTRG Virtue Gaming
# RixGG Rix.GG
# XSET XSET
# MDTY Mandatory
# GV GoodVibes
# IB ISOL-BULIL
# WYG Wygers
# ky5 keepYOURskill
# CRUSH Team Crushed
# VAC VAC Kimchi
# PG Pingu Gang
# ELQ Eloquence
# iPon iPon Esport
# EIQ Entropiq
# LBR Liberty
# MF Mindfreak
# P2N PLATOON
# AMT Aim.Attack
# ZGK ZyppanGoKill
# T1KR T1 Korea
# SMG Team SMG
# fiVe fiVe
# OOW Only One Word
# SPE Sharper Esport
# PRX Paper Rex
# LZ Team LZ
# FPX FunPlus Phoenix
# bc beastcoast
# DIG Dignitas
# HzT Hazmat.gg
# DG DETONA Gaming
# ENTB Entropiq Bravo
# LG Luminosity
# Wygers Wygers Argentina
# Procyon Procyon Team
# 28 Team 28
# COG Connect Gaming
# C9 KR Cloud9 Korea
# Tek Tek Gaming
# ROX ROX TEAM
# PSW Project SW
# AV Avant
# ROG ROG Esport
# Naura Naura
# DMB Dambis
# Hajty Hajty
# FNST Finest
# SSG Spacestation Gaming
# EvH Event Horizon
# Aion Aion Esports
# KNG Kanga Esports
# SKD SKADE
# GMB Gambit Esports
# ZØ ZEROZONE
# hPw HIGHPOWER
# STR99 STR99
# WIZ Wizards Club
# hu1 ciszej
# WOMB Wombocombo Team
# AUS Australs
# EXL E-Xolos LAZER
# EF EFuture
# xd ehehxd
# JNS Janus Esports
# KZN Kaizen Esports
# VASTA VASTA Gaming
# MR Moon Raccoons
# GP God Particles
# VLT Velocity Gaming
# VIL Villainous
# RNG Royal Never Give Up
# eStar eStar Gaming
# MJKL MAJKL
# CFA Chick Fil Ayy
# FR Team France
# GEN Genesis
# Mc McTeam
# atR alltheRAGE
# DD$ DimmaDome$
# SRN Serenity
# KR Team Korea
# ANBU ANBU Elite Gaming
# PRSM Prism Esports
# ABX Andbox
# GZ Ground Zero
# M5 Magic Five
# PRDX Paradox Esports
# TILT Tilted
# EP Enterprise Esports
# RRQ Rex Regum Qeon
# TDK Todak
# MiTH MiTH.Attitude
# Fea FeaFeaFea
# DLWZK DELIRAWOW
# CBT CBT Gaming
# KX KaiXin Esports
# SN Suning Gaming
# Toe Tales of Eastern
# XLE Exceeli Esports
# xCeed xCeed
# GES Global Esports
# OXG Oxygen Esports
# INV Team Invictus (India)
# DA Digital Athletics
# AES Anatolia Esports
# 2D Team 2D
# FYB Team FYB
# MYS Mystify
# LVI Las Vegas Inferno
# KUDO Kudos
# RR Reality Rift
# 153 153
# 5M 5MOKES
# MCS Miracles
# BRV Brave
# O5 Orgles5
# SW Santiago Wanderers
# TT Team Toxic
# Exodus Exodus
# PHX1 Phoenix1
# TH Team Heretics
# UNWN unKnown
# oveR Revolution
# iG Inside Games
# ZEIT ZEITGEIST
# 25iq avg25iq
# FC fostercare
# СС CrowСrowd
# VNG Vengeance
# ZFG ZFGaming
# HH Hollywood Hooliganz
# TF Take Flyte
# RGE Reckoning Esports
# NRG NRG Esports
# BTS Cream Real Betis
# TSW THE START W
# aNg aNg DarkHorse
# SP SeolHaeOne Prince
# S2V S2V Esports
# NT NerdTown eSport
# BDV BDV
# KAML Kamil Klein new chapter
# TM Tarren Mill
# FTM FlyToMoon
# OTE Overtime Esports
# KoG King of Gamers
# AE Alter Ego
# SF SUPERFLY
# GT Grapefruit Techniques
# EDG EDward Gaming
# VAND Vandal Only
# RED RED Canids
# CNE CoreNine Esports
# BI BE INFAMOUS
# TBP  TUBEPLE Gaming
# GodL Godlike Esports
# MSK MAJSTERSZTYK
# Empire  Team Empire
# NOX Equinox Esports
# PP PROPARTY
# AG Arctic
# AE Awake Esports
# TI Time In
# YZ Yendez
# FUT Futbolist
# eXiLe eXiLe eSports
# MM MJAOMODE
# R!OT R!OT Gaming
# PARA Paratroops
# LGC Legacy Esports
# GRV Gravitas
# ORD ORDER
# GLD Guild Esports
# Totoro Totoro Gaming
# WBG Weibo Gaming
# HaZe HaZe Clan
# VE VETERANOS e-Sports
# IH Italian Hope
# SMP Team Sampi
# SE Sangal Esports
# TN Team Name
# ISP Illinois Servers Please
# DL DREAMLAND
# DTNC Dog Team Needs Club Org
# EZ1 Eazy One Gaming
# nCars Nice Cars
# DRM Dreamwalker
# JH Jeremiah
# C9W Cloud9 White
# WTB With the boiz

# %%
df.to_csv('valorant_clean.csv')
